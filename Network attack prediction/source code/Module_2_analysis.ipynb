# %% [markdown]
# # Module:1 Data Validation Process and Preprocessing Technique

# %%
#import libraries for access and functional purpose
import pandas as p
import numpy as n
import matplotlib.pyplot as plt
import seaborn as s

# %%
#read the given dataset
df2 = p.read_csv("dataset/test1.csv")
df1 = p.read_csv("dataset/train1.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0  duration protocol_type  service flag  src_bytes  dst_bytes  \
# 0           0         0           udp    other   SF        146          0
# 1           1         0           tcp  private   S0          0          0
# 2           2         0           tcp     http   SF        232       8153
# 3           3         0           tcp     http   SF        199        420
# 4           4         0           tcp  private  REJ          0          0
#
#    land  wrong_fragment  urgent  ...  dst_host_same_srv_rate  \
# 0     0               0       0  ...                    0.00
# 1     0               0       0  ...                    0.10
# 2     0               0       0  ...                    1.00
# 3     0               0       0  ...                    1.00
# 4     0               0       0  ...                    0.07
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0  duration protocol_type   service  flag  src_bytes  dst_bytes  \
# 0           0         0           tcp   private   REJ          0          0
# 1           1         2           tcp  ftp_data    SF      12983          0
# 2           2         0          icmp     eco_i    SF         20          0
# 3           3         1           tcp    telnet  RSTO          0         15
# 4           4         0           tcp      http    SF        267      14515
#
#    land  wrong_fragment  urgent  ...  dst_host_same_srv_rate  \
# 0     0               0       0  ...                    0.00
# 1     0               0       0  ...                    0.61
# 2     0               0       0  ...                    1.00
# 3     0               0       0  ...                    0.31
# 4     0               0       0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.06                         0.00
# ...

# %%
df1.drop(columns=df1.columns[:1], axis=1,inplace=True)
df2.drop(columns=df2.columns[:1], axis=1,inplace=True)

# %%
ptype = p.Categorical(df1['protocol_type'])
ptype
# Out:
# [udp, tcp, tcp, tcp, tcp, ..., tcp, tcp, tcp, tcp, tcp]
# Length: 1000
# Categories (3, object): [icmp, tcp, udp]

# %%
df1['protocol_type'].value_counts()
# Out:
# tcp     829
# udp     108
# icmp     63
# Name: protocol_type, dtype: int64

# %%
df1['protocol_type'].nunique()
# Out:
# 3

# %%
df1['protocol_type'].unique()
# Out:
# array(['udp', 'tcp', 'icmp'], dtype=object)

# %%
df1.shape
# Out:
# (1000, 43)

# %%
#To describe the dataframe
df1.describe()
# Out:
#            duration     src_bytes     dst_bytes    land  wrong_fragment  \
# count   1000.000000  1.000000e+03    1000.00000  1000.0     1000.000000
# mean     314.051000  7.946298e+03    1392.31000     0.0        0.034000
# std     2568.216529  1.764509e+05    5813.85664     0.0        0.314552
# min        0.000000  0.000000e+00       0.00000     0.0        0.000000
# 25%        0.000000  0.000000e+00       0.00000     0.0        0.000000
# 50%        0.000000  3.550000e+01       0.00000     0.0        0.000000
# 75%        0.000000  2.610000e+02     493.25000     0.0        0.000000
# max    41285.000000  5.131424e+06  148722.00000     0.0        3.000000
#
#        urgent          hot  num_failed_logins    logged_in  num_compromised  \
# count  1000.0  1000.000000        1000.000000  1000.000000      1000.000000
# mean      0.0     0.164000           0.003000     0.387000         0.037000
# std       0.0     1.900715           0.070682     0.487307         0.638779
# ...

# %%
#Checking datatype and information about dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 43 columns):
# duration                       1000 non-null int64
# protocol_type                  1000 non-null object
# service                        1000 non-null object
# flag                           1000 non-null object
# src_bytes                      1000 non-null int64
# dst_bytes                      1000 non-null int64
# land                           1000 non-null int64
# wrong_fragment                 1000 non-null int64
# urgent                         1000 non-null int64
# hot                            1000 non-null int64
# num_failed_logins              1000 non-null int64
# logged_in                      1000 non-null int64
# num_compromised                1000 non-null int64
# root_shell                     1000 non-null int64
# su_attempted                   1000 non-null int64
# num_root                       1000 non-null int64
# ...

# %%
df1[df1.dtypes[df1.dtypes == 'float64'].index].describe()
# Out:
#        serror_rate  srv_serror_rate  rerror_rate  srv_rerror_rate  \
# count  1000.000000      1000.000000  1000.000000      1000.000000
# mean      0.296140         0.294540     0.131280         0.133150
# std       0.453927         0.453976     0.335002         0.338513
# min       0.000000         0.000000     0.000000         0.000000
# 25%       0.000000         0.000000     0.000000         0.000000
# 50%       0.000000         0.000000     0.000000         0.000000
# 75%       1.000000         1.000000     0.000000         0.000000
# max       1.000000         1.000000     1.000000         1.000000
#
#        same_srv_rate  diff_srv_rate  srv_diff_host_rate  \
# count     1000.00000    1000.000000         1000.000000
# mean         0.64220       0.069410            0.091040
# std          0.44346       0.189347            0.251394
# min          0.00000       0.000000            0.000000
# 25%          0.08000       0.000000            0.000000
# ...

# %%
p.Categorical(df1['service']).describe()
# Out:
#              counts  freqs
# categories
# IRC               2  0.002
# Z39_50            9  0.009
# auth              6  0.006
# bgp               9  0.009
# courier           6  0.006
# csnet_ns          8  0.008
# ctf               3  0.003
# daytime           2  0.002
# discard           4  0.004
# domain            5  0.005
# domain_u         59  0.059
# echo              5  0.005
# eco_i            39  0.039
# ecr_i            19  0.019
# efs               3  0.003
# exec              5  0.005
# finger           19  0.019
# ftp              16  0.016
# ftp_data         53  0.053
# gopher            6  0.006
# hostnames         5  0.005
# http            308  0.308
# http_443          2  0.002
# imap4             6  0.006
# iso_tsap          6  0.006
# klogin            3  0.003
# kshell            3  0.003
# ldap              4  0.004
# link              3  0.003
# login             5  0.005
# mtp               5  0.005
# name              3  0.003
# netbios_dgm       6  0.006
# ...

# %%
p.Categorical(df1['flag']).describe()
# Out:
#             counts  freqs
# categories
# REJ             91  0.091
# RSTO            14  0.014
# RSTR            27  0.027
# S0             291  0.291
# S1               3  0.003
# SF             572  0.572
# SH               2  0.002

# %%
p.Categorical(df1['wrong_fragment']).describe()
# Out:
#             counts  freqs
# categories
# 0              988  0.988
# 1                1  0.001
# 3               11  0.011

# %%
p.Categorical(df1['num_failed_logins']).describe()
# Out:
#             counts  freqs
# categories
# 0              998  0.998
# 1                1  0.001
# 2                1  0.001

# %%
p.Categorical(df1['num_compromised']).describe()
# Out:
#             counts  freqs
# categories
# 0              989  0.989
# 1                6  0.006
# 2                2  0.002
# 3                1  0.001
# 5                1  0.001
# 19               1  0.001

# %%
p.Categorical(df1['su_attempted']).describe()
# Out:
#             counts  freqs
# categories
# 0              999  0.999
# 1                1  0.001

# %%
p.Categorical(df1['num_outbound_cmds']).describe()
# Out:
#             counts  freqs
# categories
# 0             1000    1.0

# %%
p.Categorical(df1['serror_rate']).describe()
# Out:
#             counts  freqs
# categories
# 0.00           686  0.686
# 0.01             1  0.001
# 0.02             1  0.001
# 0.03             1  0.001
# 0.04             1  0.001
# 0.05             2  0.002
# 0.06             1  0.001
# 0.07             1  0.001
# 0.08             2  0.002
# 0.09             1  0.001
# 0.10             2  0.002
# 0.17             2  0.002
# 0.20             1  0.001
# 0.21             1  0.001
# 0.50             4  0.004
# 0.65             1  0.001
# 0.97             1  0.001
# 0.99             1  0.001
# 1.00           290  0.290

# %%
p.Categorical(df1['srv_rerror_rate']).describe()
# Out:
#             counts  freqs
# categories
# 0.00           859  0.859
# 0.03             2  0.002
# 0.08             1  0.001
# 0.10             2  0.002
# 0.11             1  0.001
# 0.20             1  0.001
# 0.25             2  0.002
# 1.00           132  0.132

# %%
p.Categorical(df1['serror_rate']).describe()
# Out:
#             counts  freqs
# categories
# 0.00           686  0.686
# 0.01             1  0.001
# 0.02             1  0.001
# 0.03             1  0.001
# 0.04             1  0.001
# 0.05             2  0.002
# 0.06             1  0.001
# 0.07             1  0.001
# 0.08             2  0.002
# 0.09             1  0.001
# 0.10             2  0.002
# 0.17             2  0.002
# 0.20             1  0.001
# 0.21             1  0.001
# 0.50             4  0.004
# 0.65             1  0.001
# 0.97             1  0.001
# 0.99             1  0.001
# 1.00           290  0.290

# %%
p.Categorical(df1['attack']).describe()
# Out:
#               counts  freqs
# categories
# back               6  0.006
# guess_passwd       1  0.001
# ipsweep           31  0.031
# neptune          346  0.346
# nmap               7  0.007
# normal           515  0.515
# pod                1  0.001
# portsweep         36  0.036
# satan             17  0.017
# smurf             17  0.017
# teardrop          11  0.011
# warezclient       12  0.012

# %%
#Checking for duplicate data
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#find sum of duplicate data
sum(df1.duplicated())
# Out:
# 0

# %%
df1.nunique()
# Out:
# duration                        53
# protocol_type                    3
# service                         58
# flag                             7
# src_bytes                      283
# dst_bytes                      351
# land                             1
# wrong_fragment                   3
# urgent                           1
# hot                             10
# num_failed_logins                3
# logged_in                        2
# num_compromised                  6
# root_shell                       1
# su_attempted                     2
# num_root                         5
# num_file_creations               3
# num_shells                       1
# num_access_files                 2
# num_outbound_cmds                1
# is_host_login                    1
# is_guest_login                   2
# count                          236
# srv_count                      107
# serror_rate                     19
# srv_serror_rate                 14
# rerror_rate                     15
# ...

# %%
#Correlation
df1.corr()
# Out:
#                              duration  src_bytes  dst_bytes  land  \
# duration                     1.000000   0.051784   0.058228   NaN
# src_bytes                    0.051784   1.000000  -0.007453   NaN
# dst_bytes                    0.058228  -0.007453   1.000000   NaN
# land                              NaN        NaN        NaN   NaN
# wrong_fragment              -0.013231  -0.004829  -0.025912   NaN
# urgent                            NaN        NaN        NaN   NaN
# hot                          0.014318   0.059839   0.042417   NaN
# num_failed_logins            0.080883  -0.001610   0.714805   NaN
# logged_in                   -0.064606   0.056319   0.293928   NaN
# num_compromised              0.086414   0.000641   0.793385   NaN
# root_shell                        NaN        NaN        NaN   NaN
# su_attempted                 0.092329  -0.001098   0.802159   NaN
# num_root                     0.060199  -0.002128   0.550316   NaN
# ...

# %%
#Checking minimum or maximum failed attempts
print("Minimum No. of Failed login attempts:", df1["num_failed_logins"].min())
print("Maximun No. of Failed login attempts:", df1["num_failed_logins"].max())
# Out:
# Minimum No. of Failed login attempts: 0
# Maximun No. of Failed login attempts: 2

# %%
#Checking minimum or maximum dst_host_count
print("Minimum No. of DST Host Count:", df1["dst_host_count"].min())
print("Maximun No. of  DST Host Count:", df1["dst_host_count"].max())
# Out:
# Minimum No. of DST Host Count: 1
# Maximun No. of  DST Host Count: 255

# %%
p.crosstab(df1.protocol_type,df1.attack)
# Out:
# attack         back  guess_passwd  ipsweep  neptune  nmap  normal  pod  \
# protocol_type
# icmp              0             0       27        0     5      13    1
# tcp               6             1        4      346     2     410    0
# udp               0             0        0        0     0      92    0
#
# attack         portsweep  satan  smurf  teardrop  warezclient
# protocol_type
# icmp                   0      0     17         0            0
# tcp                   36     12      0         0           12
# udp                    0      5      0        11            0

# %%
df1['attack'].unique()
# Out:
# array(['normal', 'neptune', 'warezclient', 'ipsweep', 'portsweep',
#        'teardrop', 'nmap', 'satan', 'smurf', 'pod', 'back',
#        'guess_passwd'], dtype=object)

# %%
df1.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'attack', 'last_flag'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
       'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
       'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
       'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
       'num_access_files', 'num_outbound_cmds', 'is_host_login',
       'is_guest_login', 'count', 'srv_count', 'serror_rate',
       'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
       'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
       'dst_host_srv_count', 'dst_host_same_srv_rate',
       'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
       'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
       'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
       'dst_host_srv_rerror_rate', 'attack', 'last_flag']
le = LabelEncoder()
for i in var_mod:
    df1[i] = le.fit_transform(df1[i]).astype(str)

# %%
df1.head()
# Out:
#   duration protocol_type service flag src_bytes dst_bytes land wrong_fragment  \
# 0        0             2      38    5        37         0    0              0
# 1        0             1      42    3         0         0    0              0
# 2        0             1      21    5        86       304    0              0
# 3        0             1      21    5        55       100    0              0
# 4        0             1      42    0         0         0    0              0
#
#   urgent hot  ... dst_host_same_srv_rate dst_host_diff_srv_rate  \
# 0      0   0  ...                      0                     40
# 1      0   0  ...                     10                      5
# 2      0   0  ...                     85                      0
# 3      0   0  ...                     85                      0
# 4      0   0  ...                      7                      7
#
#   dst_host_same_src_port_rate dst_host_srv_diff_host_rate  \
# ...
